# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
#getting data
df = pd.read_csv('takeoffcolumns.csv')
project = df

# %%
project.loc[:,"Within 6 Months" ] = 0
adopt = project.loc[:, "Outcome Type"] == "Adoption"
sixm = project.loc[:, ]

# %%
project = project.rename(columns={"Duration":"Duration (days)"})

# %%
duration = project.loc[:, "Duration (days)"]
duration = duration.astype('str')
duration = duration.str.slice(0,-5)

# %%
project.loc[:, "Duration (days)"] = 0
project.loc[:, "Duration (days)"] = duration

# %%
#years into days
intakeage = project.loc[:, "Age upon Intake"]
yearsbool = intakeage.str.contains("years")
years = intakeage[yearsbool]
numyears = years.str.slice(0,-6).astype('int')
yearsdays = numyears.astype('str')
yearsdays = numyears * 365
yearsdays = yearsdays.astype("str")
project.loc[yearsbool, "Age upon Intake"] = yearsdays

# %%
#months into days
intakeage = project.loc[:, "Age upon Intake"]
yearsbool = intakeage.str.contains("months")
years = intakeage[yearsbool]
numyears = years.str.slice(0,-7).astype('int')
yearsdays = numyears.astype('str')
yearsdays = numyears * 30
yearsdays = yearsdays.astype("str")
project.loc[yearsbool, "Age upon Intake"] = yearsdays

# %%
#weeks into days
intakeage = project.loc[:, "Age upon Intake"]
yearsbool = intakeage.str.contains("weeks")
years = intakeage[yearsbool]
numyears = years.str.slice(0,-6).astype('int')
yearsdays = numyears.astype('str')
yearsdays = numyears * 7
yearsdays = yearsdays.astype("str")
project.loc[yearsbool, "Age upon Intake"] = yearsdays

# %%
#year into days
intakeage = project.loc[:, "Age upon Intake"]
yearsbool = intakeage.str.contains("year")
years = intakeage[yearsbool]
numyears = years.str.slice(0,-5).astype('int')
yearsdays = numyears.astype('str')
yearsdays = numyears * 365
yearsdays = yearsdays.astype("str")
project.loc[yearsbool, "Age upon Intake"] = yearsdays

# %%
#month into days
intakeage = project.loc[:, "Age upon Intake"]
yearsbool = intakeage.str.contains("month")
years = intakeage[yearsbool]
numyears = years.str.slice(0,-6).astype('int')
yearsdays = numyears.astype('str')
yearsdays = numyears * 30
yearsdays = yearsdays.astype("str")
project.loc[yearsbool, "Age upon Intake"] = yearsdays

# %%
#week into days
intakeage = project.loc[:, "Age upon Intake"]
yearsbool = intakeage.str.contains("week")
years = intakeage[yearsbool]
numyears = years.str.slice(0,-5).astype('int')
yearsdays = numyears.astype('str')
yearsdays = numyears * 7
yearsdays = yearsdays.astype("str")
project.loc[yearsbool, "Age upon Intake"] = yearsdays

# %%
#days
intakeage = project.loc[:, "Age upon Intake"]
yearsbool = intakeage.str.contains("days")
years = intakeage[yearsbool]
numyears = years.str.slice(0,-5).astype('int')
yearsdays = numyears.astype('str')
project.loc[yearsbool, "Age upon Intake"] = yearsdays

# %%
#day
intakeage = project.loc[:, "Age upon Intake"]
yearsbool = intakeage.str.contains("day")
years = intakeage[yearsbool]
numyears = years.str.slice(0,-4).astype('int')
yearsdays = numyears.astype('str')
project.loc[yearsbool, "Age upon Intake"] = yearsdays

# %%
#years into days
intakeage = project.loc[:, "Age upon Outcome"]
yearsbool = intakeage.str.contains("years")
years = intakeage[yearsbool]
numyears = years.str.slice(0,-6).astype('int')
yearsdays = numyears.astype('str')
yearsdays = numyears * 365
yearsdays = yearsdays.astype("str")
project.loc[yearsbool, "Age upon Outcome"] = yearsdays

# %%
#months into days
intakeage = project.loc[:, "Age upon Outcome"]
yearsbool = intakeage.str.contains("months")
years = intakeage[yearsbool]
numyears = years.str.slice(0,-7).astype('int')
yearsdays = numyears.astype('str')
yearsdays = numyears * 30
yearsdays = yearsdays.astype("str")
project.loc[yearsbool, "Age upon Outcome"] = yearsdays

# %%
#weeks into days
intakeage = project.loc[:, "Age upon Outcome"]
yearsbool = intakeage.str.contains("weeks")
years = intakeage[yearsbool]
numyears = years.str.slice(0,-6).astype('int')
yearsdays = numyears.astype('str')
yearsdays = numyears * 7
yearsdays = yearsdays.astype("str")
project.loc[yearsbool, "Age upon Outcome"] = yearsdays

# %%
#year into days
intakeage = project.loc[:, "Age upon Outcome"]
yearsbool = intakeage.str.contains("year")
years = intakeage[yearsbool]
numyears = years.str.slice(0,-5).astype('int')
yearsdays = numyears.astype('str')
yearsdays = numyears * 365
yearsdays = yearsdays.astype("str")
project.loc[yearsbool, "Age upon Outcome"] = yearsdays

# %%
#month into days
intakeage = project.loc[:, "Age upon Outcome"]
yearsbool = intakeage.str.contains("month")
years = intakeage[yearsbool]
numyears = years.str.slice(0,-6).astype('int')
yearsdays = numyears.astype('str')
yearsdays = numyears * 30
yearsdays = yearsdays.astype("str")
project.loc[yearsbool, "Age upon Outcome"] = yearsdays

# %%
#week into days
intakeage = project.loc[:, "Age upon Outcome"]
yearsbool = intakeage.str.contains("week")
years = intakeage[yearsbool]
numyears = years.str.slice(0,-5).astype('int')
yearsdays = numyears.astype('str')
yearsdays = numyears * 7
yearsdays = yearsdays.astype("str")
project.loc[yearsbool, "Age upon Outcome"] = yearsdays

# %%
#days
intakeage = project.loc[:, "Age upon Outcome"]
yearsbool = intakeage.str.contains("days")
years = intakeage[yearsbool]
numyears = years.str.slice(0,-5).astype('int')
yearsdays = numyears.astype('str')
project.loc[yearsbool, "Age upon Outcome"] = yearsdays

# %%
#day
intakeage = project.loc[:, "Age upon Outcome"]
yearsbool = intakeage.str.contains("day")
years = intakeage[yearsbool]
numyears = years.str.slice(0,-4).astype('int')
yearsdays = numyears.astype('str')
project.loc[yearsbool, "Age upon Outcome"] = yearsdays

# %%
project = project.rename(columns={"Age upon Intake": "Intake Age (days)"})
project = project.rename(columns={"Age upon Outcome": "Outcome Age (days)"})
project.loc[:, "Outcome Age (days)"] = project.loc[:, "Outcome Age (days)"].astype("int")
project.loc[:, "Intake Age (days)"] = project.loc[:, "Intake Age (days)"].astype("int")
project.head()
# Out:
#    Intake DateTime    Intake Type Intake Condition Animal Type  \
# 0    1/3/2019 0:00          Stray           Normal         Dog
# 1   5/12/2022 0:00  Public Assist           Normal         Cat
# 2  10/15/2021 0:00          Stray           Normal         Cat
# 3   6/18/2020 0:00          Stray           Normal         Cat
# 4   7/11/2015 0:00          Stray           Normal         Dog
#
#   Intake Age (days)               Breed         Color DateTime Outcome  \
# 0               730          BEAGLE MIX      Tricolor    1/8/2019 0:00
# 1               730  DOMESTIC SHORTHAIR  Orange Tabby   5/12/2022 0:00
# 2               180  DOMESTIC SHORTHAIR   Brown Tabby  10/20/2021 0:00
# 3                28  DOMESTIC SHORTHAIR   Cream Tabby   7/23/2020 0:00
# 4               150            PIT BULL   Brown/White  11/28/2015 0:00
#
#   Outcome Type Sex upon Outcome Outcome Age (days) Date of Birth  Mix  \
# 0     Transfer    Neutered Male                730      1/3/2017    1
# ...

# %%
#within 6 months column
project.loc[:, "Duration (days)"] = project.loc[:, "Duration (days)"].astype('int')
withinsix = project.loc[:, "Duration (days)"] < 181
adoption = project.loc[:, "Outcome Type"] == "Adoption"
both = withinsix & adoption
project.loc[both, "Within 6 Months"] = 1
project.head()
# Out:
#    Intake DateTime    Intake Type Intake Condition Animal Type  \
# 0    1/3/2019 0:00          Stray           Normal         Dog
# 1   5/12/2022 0:00  Public Assist           Normal         Cat
# 2  10/15/2021 0:00          Stray           Normal         Cat
# 3   6/18/2020 0:00          Stray           Normal         Cat
# 4   7/11/2015 0:00          Stray           Normal         Dog
#
#   Intake Age (days)               Breed         Color DateTime Outcome  \
# 0               730          BEAGLE MIX      Tricolor    1/8/2019 0:00
# 1               730  DOMESTIC SHORTHAIR  Orange Tabby   5/12/2022 0:00
# 2               180  DOMESTIC SHORTHAIR   Brown Tabby  10/20/2021 0:00
# 3                28  DOMESTIC SHORTHAIR   Cream Tabby   7/23/2020 0:00
# 4               150            PIT BULL   Brown/White  11/28/2015 0:00
#
#   Outcome Type Sex upon Outcome Outcome Age (days) Date of Birth  Mix  \
# 0     Transfer    Neutered Male                730      1/3/2017    1
# ...

# %%
#turned breed with / into mix breed
mixes = project.loc[:, "Breed"]
mixes = mixes.str.contains('/')
project.loc[mixes, "Mix"] = 1
project.head()
# Out:
#    Intake DateTime    Intake Type Intake Condition Animal Type  \
# 0    1/3/2019 0:00          Stray           Normal         Dog
# 1   5/12/2022 0:00  Public Assist           Normal         Cat
# 2  10/15/2021 0:00          Stray           Normal         Cat
# 3   6/18/2020 0:00          Stray           Normal         Cat
# 4   7/11/2015 0:00          Stray           Normal         Dog
#
#   Intake Age (days)               Breed         Color DateTime Outcome  \
# 0               730          BEAGLE MIX      Tricolor    1/8/2019 0:00
# 1               730  DOMESTIC SHORTHAIR  Orange Tabby   5/12/2022 0:00
# 2               180  DOMESTIC SHORTHAIR   Brown Tabby  10/20/2021 0:00
# 3                28  DOMESTIC SHORTHAIR   Cream Tabby   7/23/2020 0:00
# 4               150            PIT BULL   Brown/White  11/28/2015 0:00
#
#   Outcome Type Sex upon Outcome Outcome Age (days) Date of Birth  Mix  \
# 0     Transfer    Neutered Male                730      1/3/2017    1
# ...

# %%
project.to_csv("Clean Data.csv")

# %%
#adotped dogs withing six months
six = project.loc[:,"Within 6 Months"] == 1
dog = project.loc[:, "Animal Type"] == "Dog"
sixndog = (six & dog)
project.loc[sixndog, "Breed"]
# Out:
# 4                                        PIT BULL
# 5                             CHIHUAHUA SHORTHAIR
# 7                             CHIHUAHUA SHORTHAIR
# 10       AUSTRALIAN CATTLE DOG/LABRADOR RETRIEVER
# 26                            TIBETAN SPANIEL MIX
#                            ...
# 97259                        SCOTTISH TERRIER MIX
# 97260                  GERMAN SHEPHERD/ROTTWEILER
# 97263                                   CATAHOULA
# 97265            AUSTRALIAN CATTLE DOG/BLOODHOUND
# 97269                      LABRADOR RETRIEVER MIX
# Name: Breed, Length: 29283, dtype: object

# %%
#dog adopted - 2062
normdog = project.loc[:,"Animal Type"] == "Dog"
dogbreednum = project.loc[normdog, "Breed"].value_counts()
dogbreed = project.loc[normdog, "Breed"]
dogbreed = dogbreed.unique()
dogbreed = pd.Series(dogbreed)
dogframe = dogbreed.to_frame(name="Dog Breed")
dogframe.head()
# Out:
#                                   Dog Breed
# 0                                BEAGLE MIX
# 1                                  PIT BULL
# 2                       CHIHUAHUA SHORTHAIR
# 3  AUSTRALIAN CATTLE DOG/LABRADOR RETRIEVER
# 4                               MALTESE MIX

# %%
dogframe.loc[:, "Adoption (%)"] = 0
dogframe.head()
# Out:
#                                   Dog Breed  Adoption (%)
# 0                                BEAGLE MIX             0
# 1                                  PIT BULL             0
# 2                       CHIHUAHUA SHORTHAIR             0
# 3  AUSTRALIAN CATTLE DOG/LABRADOR RETRIEVER             0
# 4                               MALTESE MIX             0

# %%
#df with all dogs
workin = project.loc[normdog, :]
firstval = workin.loc[:, "Breed"].value_counts()
firstval = firstval.reset_index()
firstval.head(10)
firstval.to_csv('dogbreed.csv')

# %%
#df with all dogs that were adopted within 6 months
secval = workin.loc[sixndog, "Breed"].value_counts()
secval = secval.reset_index()
secval.head()
# Out:
#                      Breed  count
# 0   LABRADOR RETRIEVER MIX   3051
# 1  CHIHUAHUA SHORTHAIR MIX   2486
# 2             PIT BULL MIX   2184
# 3      GERMAN SHEPHERD MIX   1443
# 4                 PIT BULL    874

# %%
#comparing dog adoptions
finalmente = firstval.merge(secval, how='left', left_on="Breed", right_on="Breed")
finalmente
# Out:
#                                        Breed  count_x  count_y
# 0                     LABRADOR RETRIEVER MIX     4616   3051.0
# 1                    CHIHUAHUA SHORTHAIR MIX     4061   2486.0
# 2                               PIT BULL MIX     3866   2184.0
# 3                        GERMAN SHEPHERD MIX     2078   1443.0
# 4                                   PIT BULL     1440    874.0
# ...                                      ...      ...      ...
# 2057  BORDER COLLIE/GERMAN SHORTHAIR POINTER        1      1.0
# 2058             POINTER/AUSTRALIAN SHEPHERD        1      1.0
# 2059    RHOD RIDGEBACK/AUSTRALIAN CATTLE DOG        1      NaN
# 2060             CAIRN TERRIER/CAIRN TERRIER        1      1.0
# 2061        AUSTRALIAN CATTLE DOG/BLOODHOUND        1      1.0
#
# [2062 rows x 3 columns]

# %%
overhundo = finalmente.loc[:, 'count_x'] > 100

# %%
finalhundo = finalmente.loc[overhundo, :]

# %%
tru = finalhundo.loc[:, 'count_y'].isna()
finalhundo.loc[tru,'count_y'] = 0
div = finalhundo.loc[:,"count_y"] / finalhundo.loc[:, "count_x"]
div = div * 100
div = div.round(2)
finalhundo.loc[:,"Adoption %"] = div
finalhundo = finalhundo.drop(columns=['count_x', 'count_y'])
# Out:
# C:\Users\15869\AppData\Local\Temp\ipykernel_19472\924433581.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finalhundo.loc[:,"Adoption %"] = div

# %%
dogvisual = finalhundo
dogvisual
# Out:
#                                        Breed  Adoption %
# 0                     LABRADOR RETRIEVER MIX       66.10
# 1                    CHIHUAHUA SHORTHAIR MIX       61.22
# 2                               PIT BULL MIX       56.49
# 3                        GERMAN SHEPHERD MIX       69.44
# 4                                   PIT BULL       60.69
# ..                                       ...         ...
# 56        AMERICAN STAFFORDSHIRE TERRIER MIX       63.21
# 57          LABRADOR RETRIEVER/BORDER COLLIE       62.86
# 58               PIT BULL/LABRADOR RETRIEVER       56.31
# 59  LABRADOR RETRIEVER/AUSTRALIAN CATTLE DOG       65.69
# 60                        CHIHUAHUA LONGHAIR       49.02
#
# [61 rows x 2 columns]

# %%
topdogvis = dogvisual.sort_values("Adoption %").tail(10)
topdogvis
# Out:
#                                  Breed  Adoption %
# 19            JACK RUSSELL TERRIER MIX       69.58
# 14                       CATAHOULA MIX       69.62
# 10                   BORDER COLLIE MIX       72.57
# 45              MINIATURE PINSCHER MIX       73.10
# 29               AUSTRALIAN CATTLE DOG       73.45
# 8                      GERMAN SHEPHERD       75.16
# 26                      SIBERIAN HUSKY       76.77
# 39  GERMAN SHEPHERD/LABRADOR RETRIEVER       78.05
# 16                  SIBERIAN HUSKY MIX       79.29
# 51                       BLUE LACY MIX       80.49

# %%
sixm = project.loc[:, "Within 6 Months"] == 1
catdog = project.loc[sixm, 'Animal Type'].value_counts()
catdog
# Out:
# Animal Type
# Dog    29283
# Cat    26397
# Name: count, dtype: int64

# %%
catstotal = project.loc[:, 'Animal Type'] == "Cat"
catstotal
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 97269    False
# 97270     True
# 97271     True
# 97272    False
# 97273    False
# Name: Animal Type, Length: 97274, dtype: bool

# %%
fullcat = project.loc[catstotal, "Animal Type"]
fullcatnum = fullcat.shape[0]
fullcatnum
# Out:
# 50231

# %%
dogstotal = project.loc[:, 'Animal Type'] == "Dog"
fulldog = project.loc[dogstotal, 'Animal Type']
fulldognum = fulldog.shape[0]
fulldognum
# Out:
# 47043

# %%
catdog = catdog.to_frame()
catdog
# Out:
#              count
# Animal Type
# Dog          29283
# Cat          26397

# %%
catdog = catdog.reset_index()

# %%
catdog.loc[0,"count"] = catdog.loc[0,"count"] / fullcatnum
catdog.loc[1,"count"] = catdog.loc[1,"count"] / fulldognum

# %%
catdog.loc[:, "count"] = (catdog.loc[:, "count"] * 100).round(2)

# %%
catdog = catdog.rename(columns={"count":"Adoption %"})
catdog
# Out:
#   Animal Type  Adoption %
# 0         Dog       58.30
# 1         Cat       56.11

# %%
catvals = project.loc[catstotal, "Breed"].value_counts().reset_index()
kitty = catstotal & sixm
catval = project.loc[kitty, "Breed"].value_counts().reset_index()
catvisualval = catvals.merge(catval, how='left', left_on="Breed", right_on="Breed")

# %%
catoverhund = catvisualval.loc[:, 'count_x'] > 100
catoverhund
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#       ...
# 91    False
# 92    False
# 93    False
# 94    False
# 95    False
# Name: count_x, Length: 96, dtype: bool

# %%
catfinalhund = catvisualval.loc[catoverhund, :]

# %%
catdiv = ((catfinalhund.loc[:,"count_y"] / catfinalhund.loc[:, 'count_x']) * 100).round(2)
catfinalhund = catfinalhund.drop(columns=["count_x", "count_y"])
catfinalhund.loc[:, "Adoption %"] = catdiv

# %%
catfinalten = catfinalhund.sort_values('Adoption %').tail(10)

# %%
sixd = (project.loc[:, "Within 6 Months"] == 1) & (project.loc[:, "Animal Type"] == "Dog")
sixc = (project.loc[:, "Within 6 Months"] == 1) & (project.loc[:, "Animal Type"] == "Cat")

# %%
project.loc[:, "Outcome Age (days)"] = project.loc[:, "Outcome Age (days)"].astype('int')
project.head()
# Out:
#    Intake DateTime    Intake Type Intake Condition Animal Type  \
# 0    1/3/2019 0:00          Stray           Normal         Dog
# 1   5/12/2022 0:00  Public Assist           Normal         Cat
# 2  10/15/2021 0:00          Stray           Normal         Cat
# 3   6/18/2020 0:00          Stray           Normal         Cat
# 4   7/11/2015 0:00          Stray           Normal         Dog
#
#   Intake Age (days)               Breed         Color DateTime Outcome  \
# 0               730          BEAGLE MIX      Tricolor    1/8/2019 0:00
# 1               730  DOMESTIC SHORTHAIR  Orange Tabby   5/12/2022 0:00
# 2               180  DOMESTIC SHORTHAIR   Brown Tabby  10/20/2021 0:00
# 3                28  DOMESTIC SHORTHAIR   Cream Tabby   7/23/2020 0:00
# 4               150            PIT BULL   Brown/White  11/28/2015 0:00
#
#   Outcome Type Sex upon Outcome Outcome Age (days) Date of Birth  Mix  \
# 0     Transfer    Neutered Male                730      1/3/2017    1
# ...

# %%
averagedog = project.loc[sixd, "Outcome Age (days)"].mean()
averagecat = project.loc[sixc, "Outcome Age (days)"].mean()

# %%
average = [['Dog', averagedog], ['Cat', averagecat]]
dfave = pd.DataFrame(average, columns=['Animal Type', 'Age (days)'])
dfave
# Out:
#   Animal Type  Age (days)
# 0         Dog  615.398012
# 1         Cat  353.020040

# %%
monthsage = (dfave.loc[:, "Age (days)"] / 30).round(2)
monthsage
# Out:
# 0    20.51
# 1    11.77
# Name: Age (days), dtype: float64

# %%
x = dfave.loc[:, "Animal Type"]
y = monthsage
plt.ylim(0,24)
plt.bar(x, y)
plt.title("Average Age (in months) of Adopting a Cat or Dog")
plt.xlabel("Animal Type")
plt.ylabel("Age (months)")
plt.show()

# %%
x = catdog.loc[:, "Animal Type"]
y = catdog.loc[:, "Adoption %"]
plt.ylim(0,100)
plt.bar(x, y)
plt.title("Adoption Percentange Beteween Cats and Dogs")
plt.xlabel("Animal Type")
plt.ylabel("Percentage")
plt.show()

# %%
x = topdogvis.loc[:, 'Adoption %']
y = topdogvis.loc[:, 'Breed']
plt.xlim(0,100)
plt.barh(y, x)
plt.title("Top Ten Dog Breed Adoption Percentage")
plt.ylabel("Dog Breed")
plt.xlabel("Percentage")

plt.show()

# %%
x = catfinalten.loc[:, 'Adoption %']
y = catfinalten.loc[:, 'Breed']
plt.xlim(0,100)
plt.barh(y, x)
plt.title("Top Ten Cat Breed Adoption Percentage")
plt.ylabel("Cat Breed")
plt.xlabel("Percentage")
plt.show()

# %%
#blue lacy dogs
project.loc[:,"Blue Lacy"] = 0
boolblue = project.loc[:, "Breed"].str.contains("BLUE LACY")
project.loc[boolblue, "Blue Lacy"] = 1

# %%
#siberian husky dogs
project.loc[:,"Siberian Husky"] = 0
boolsiber = project.loc[:, "Breed"].str.contains("SIBERIAN HUSKY")
project.loc[boolsiber, "Siberian Husky"] = 1

# %%
#german shepherd dogs
project.loc[:,"German Shepherd"] = 0
boolgerman = project.loc[:, "Breed"].str.contains("GERMAN SHEPHERD")
project.loc[boolgerman, "German Shepherd"] = 1

# %%
#labarador dogs
project.loc[:,"Labrador Retriever"] = 0
boollab = project.loc[:, "Breed"].str.contains("LABRADOR RETRIEVER")
project.loc[boollab, "Labrador Retriever"] = 1

# %%
#australian cattle dogs
project.loc[:,"Australian Cattle"] = 0
boolaust = project.loc[:, "Breed"].str.contains("AUSTRALIAN CATTLE")
project.loc[boolaust, "Australian Cattle"] = 1

# %%
#miniature pinscher dogs
project.loc[:,"Miniature Pinscher"] = 0
boolmini = project.loc[:, "Breed"].str.contains("MINIATURE PINSCHER")
project.loc[boolmini, "Miniature Pinscher"] = 1

# %%
#border collie dogs
project.loc[:,"Border Collie"] = 0
boolbord = project.loc[:, "Breed"].str.contains("BORDER COLLIE")
project.loc[boolbord, "Border Collie"] = 1

# %%
#border collie dogs
project.loc[:,"Border Collie"] = 0
boolbord = project.loc[:, "Breed"].str.contains("BORDER COLLIE")
project.loc[boolbord, "Border Collie"] = 1

# %%
#catahoula dogs
project.loc[:,"Catahoula"] = 0
boolcata = project.loc[:, "Breed"].str.contains("CATAHOULA")
project.loc[boolcata, "Catahoula"] = 1

# %%
#jack russell terrier dogs
project.loc[:,"Jack Russell Terrier"] = 0
booljack = project.loc[:, "Breed"].str.contains("JACK RUSSELL")
project.loc[booljack, "Jack Russell Terrier"] = 1

# %%
#chihuahua dogs
project.loc[:,"Chihuahua"] = 0
boolchih = project.loc[:, "Breed"].str.contains("CHIHUAHUA")
project.loc[boolchih, "Chihuahua"] = 1

# %%
#pitbull dogs
project.loc[:,"Pitbull"] = 0
boolpit = project.loc[:, "Breed"].str.contains("PIT BULL")
project.loc[boolpit, "Pitbull"] = 1

# %%
#dachshund dogs
project.loc[:,"Dachshund"] = 0
booldach = project.loc[:, "Breed"].str.contains("DACHSHUND")
project.loc[booldach, "Dachshund"] = 1

# %%
#domestic longhair cats
project.loc[:,"Domestic Longhair"] = 0
boollong = project.loc[:, "Breed"].str.contains("DOMESTIC LONGHAIR")
project.loc[boollong, "Domestic Longhair"] = 1

# %%
#domestic medium hair cats
project.loc[:,"Domestic Medium Hair"] = 0
boolmed = project.loc[:, "Breed"].str.contains("DOMESTIC MEDIUM")
project.loc[boolmed, "Domestic Medium Hair"] = 1

# %%
#siamese cats
project.loc[:,"Siamese"] = 0
boolsiam = project.loc[:, "Breed"].str.contains("SIAMESE")
project.loc[boolsiam, "Siamese"] = 1

# %%
#domestic shorthair cats
project.loc[:,"Domestic Shorthair"] = 0
boolshort = project.loc[:, "Breed"].str.contains("DOMESTIC SHORTHAIR")
project.loc[boolshort, "Domestic Shorthair"] = 1

# %%
#snowshoe cats
project.loc[:,"Snowshoe"] = 0
boolsnow = project.loc[:, "Breed"].str.contains("SNOWSHOE")
project.loc[boolsnow, "Snowshoe"] = 1

# %%
#american shorthair cats
project.loc[:,"American Shorthair"] = 0
boolams = project.loc[:, "Breed"].str.contains("AMERICAN SHORTHAIR")
project.loc[boolams, "American Shorthair"] = 1

# %%
mldf = project.copy()

# %%
intakecond = mldf.loc[:, "Intake Condition"].value_counts().index
intakecond
# Out:
# Index(['Normal', 'Injured', 'Nursing', 'Sick', 'Neonatal', 'Other', 'Medical',
#        'Aged', 'Feral', 'Pregnant', 'Behavior', 'Med Attn', 'Unknown',
#        'Neurologic', 'Med Urgent', 'Space', 'Parvo', 'Congenital'],
#       dtype='object', name='Intake Condition')

# %%
for i in range(0,intakecond.shape[0]):
    mldf.loc[:,"Intake Condition " + intakecond[i]] = 0
    boolintake = mldf.loc[:, "Intake Condition"] == intakecond[i]
    mldf.loc[boolintake, "Intake Condition " + intakecond[i]] = 1

# %%
intaketype = mldf.loc[:, "Intake Type"].value_counts().index
for i in range(0,intaketype.shape[0]):
    mldf.loc[:,"Intake Type " + intaketype[i]] = 0
    boolintake = mldf.loc[:, "Intake Type"] == intaketype[i]
    mldf.loc[boolintake, "Intake Type " + intaketype[i]] = 1

# %%
animtype = mldf.loc[:, "Animal Type"].value_counts().index
for i in range(0,animtype.shape[0]):
    mldf.loc[:,"Animal Type " + animtype[i]] = 0
    boolintake = mldf.loc[:, "Animal Type"] == animtype[i]
    mldf.loc[boolintake, "Animal Type " + animtype[i]] = 1

# %%
sextype = mldf.loc[:, "Sex upon Outcome"].value_counts().index
for i in range(0,sextype.shape[0]):
    mldf.loc[:,"Sex - " + sextype[i]] = 0
    boolintake = mldf.loc[:, "Sex upon Outcome"] == sextype[i]
    mldf.loc[boolintake, "Sex - " + sextype[i]] = 1

# %%
mldf
# Out:
#        Intake DateTime      Intake Type Intake Condition Animal Type  \
# 0        1/3/2019 0:00            Stray           Normal         Dog
# 1       5/12/2022 0:00    Public Assist           Normal         Cat
# 2      10/15/2021 0:00            Stray           Normal         Cat
# 3       6/18/2020 0:00            Stray           Normal         Cat
# 4       7/11/2015 0:00            Stray           Normal         Dog
# ...                ...              ...              ...         ...
# 97269   11/2/2017 0:00            Stray           Normal         Dog
# 97270   6/27/2018 0:00  Owner Surrender           Normal         Cat
# 97271  10/22/2017 0:00            Stray           Normal         Cat
# 97272   12/4/2017 0:00            Stray           Normal         Dog
# 97273   4/25/2022 0:00            Stray           Normal         Dog
#
#       Intake Age (days)                            Breed         Color  \
# ...

# %%
mldf = mldf.drop(columns=['Intake DateTime', 'Intake Type', 'Intake Condition', 'Animal Type', 'Breed', 'Color', 'DateTime Outcome', 'Outcome Type', 'Sex upon Outcome', 'Outcome Age (days)', 'Date of Birth', 'Duration (days)'])
mldf
# Out:
#       Intake Age (days)  Mix  Within 6 Months  Blue Lacy  Siberian Husky  \
# 0                   730    1                0          0               0
# 1                   730    0                0          0               0
# 2                   180    0                1          0               0
# 3                    28    0                1          0               0
# 4                   150    0                1          0               0
# ...                 ...  ...              ...        ...             ...
# 97269                30    1                1          0               0
# 97270               730    0                1          0               0
# 97271               730    1                0          0               0
# 97272               730    1                0          0               0
# 97273               270    1                0          0               0
#
#        German Shepherd  Labrador Retriever  Australian Cattle  \
# ...

# %%
X = mldf.copy()
X = X.drop(columns=['Within 6 Months'])
X
# Out:
#       Intake Age (days)  Mix  Blue Lacy  Siberian Husky  German Shepherd  \
# 0                   730    1          0               0                0
# 1                   730    0          0               0                0
# 2                   180    0          0               0                0
# 3                    28    0          0               0                0
# 4                   150    0          0               0                0
# ...                 ...  ...        ...             ...              ...
# 97269                30    1          0               0                0
# 97270               730    0          0               0                0
# 97271               730    1          0               0                0
# 97272               730    1          0               0                0
# 97273               270    1          0               0                0
#
#        Labrador Retriever  Australian Cattle  Miniature Pinscher  \
# ...

# %%
y = mldf.loc[:, "Within 6 Months"]
y
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 97269    1
# 97270    1
# 97271    0
# 97272    0
# 97273    0
# Name: Within 6 Months, Length: 97274, dtype: int64

# %%
xpract = X.iloc[0:80000, :]
ypract = y.iloc[0:80000]

# %%
knearn = KNeighborsClassifier()

# %%
knearn.fit(xpract, ypract)
# Out:
# KNeighborsClassifier()

# %%
predicthalf = knearn.predict(X.iloc[80000:, :])
predicthalf
# Out:
# array([0, 1, 1, ..., 0, 1, 1], dtype=int64)

# %%
prevals = (y.iloc[80000:] == predicthalf).value_counts()
prevals
# Out:
# Within 6 Months
# True     14734
# False     2540
# Name: count, dtype: int64

# %%
prevals[True] / 17274
# Out:
# 0.8529582030797731

# %%
randfor = RandomForestClassifier(n_estimators=400, random_state=0, max_features=0.1)

# %%
randfor.fit(xpract, ypract)
# Out:
# RandomForestClassifier(max_features=0.1, n_estimators=400, random_state=0)

# %%
predicthalf2 = randfor.predict(X.iloc[80000:, :])
predicthalf2
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int64)

# %%
prevals2 = (y.iloc[80000:] == predicthalf2).value_counts()
prevals2
# Out:
# Within 6 Months
# True     14894
# False     2380
# Name: count, dtype: int64

# %%
prevals2[True] / 17274
# Out:
# 0.8622206784763228

# %%
dectree = DecisionTreeClassifier()

# %%
dectree.fit(xpract, ypract)
# Out:
# DecisionTreeClassifier()

# %%
predicthalf3 = dectree.predict(X.iloc[80000:, :])
predicthalf3
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int64)

# %%
prevals3 = (y.iloc[80000:] == predicthalf3).value_counts()
prevals3
# Out:
# Within 6 Months
# True     14768
# False     2506
# Name: count, dtype: int64

# %%
prevals3[True] / 17274
# Out:
# 0.8549264791015398

# %%
plt.figure(figsize=(50,50))
tree.plot_tree(dectree, max_depth=3, fontsize=30, feature_names=xpract.columns, proportion=True)
plt.show()
